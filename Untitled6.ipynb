# %% [markdown]
# <a href="https://colab.research.google.com/github/raylanrodriguescosta-sketch/Atividade.py/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
usuario = input("Digite o usuário: ")
senha = input("Digite a senha: ")

if usuario == "aluno" and senha == "12345":
    print("Seja bem-vindo")
else:
    print("Acesso negado")
# Out:
# Digite o usuário: aluno
# Digite a senha: 12345
# Seja bem-vindo
