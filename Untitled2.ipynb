# %% [markdown]
# <a href="https://colab.research.google.com/github/raylanrodriguescosta-sketch/Atividade.py/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
peso = float(input("Digite seu peso: "))
altura = float(input("Digite sua altura: "))

imc = peso / (altura * altura)

print("Seu IMC é:", imc)

if imc < 18.5:
    print("Abaixo do peso")
elif imc < 25:
    print("Peso normal")
elif imc < 30:
    print("Sobrepeso")
else:
    print("Obesidade")
# Out:
# Digite seu peso: 70
# Digite sua altura: 175
# Seu IMC é: 0.002285714285714286
# Abaixo do peso
